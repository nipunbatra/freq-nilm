# %%
import sys
sys.path.append("../code/")
from sklearn.metrics import mean_absolute_error
from dataloader import APPLIANCE_ORDER, get_train_test

# %%
num_folds = 5
fold_num = 0
train, test = get_train_test(num_folds=num_folds, fold_num=fold_num)

# %%
train.shape
# Out:
# (54, 6, 112, 24)

# %%
APPLIANCE_ORDER
# Out:
# ['aggregate', 'hvac', 'fridge', 'dr', 'dw', 'mw']

# %%
train.shape
# Out:
# (54, 6, 112, 24)

# %%
train[:, 5, :, :].mean(axis=1).mean(axis=1)
# Out:
# array([  8.88100198,   9.78051215,   1.66083829,  19.19930557,
#         37.74277027,   5.61596602,  11.31340524,   2.79228051,
#          8.03829987,  23.3717944 ,  15.57405755,   5.68551586,
#          5.66497397,   0.44170387,   9.96214659,   2.65448289,
#          8.07309648,   3.29483507,   2.29379961,   9.4328373 ,
#         15.57544645,   8.77741197,   2.42421876,   0.52731275,
#          2.81666666,   7.70974082,   4.76672867,  12.78177703,
#          9.07834201,   5.38291791,   8.38689235,   5.97420636,
#         11.92070933,   2.36935144,   6.0840216 ,   2.49951638,
#          5.13198165,   6.43764882,   4.88088417,   3.6889261 ,
#          7.46735492,   5.94143725,  19.41217759,   5.2812934 ,
#          6.68776663,  15.37747395,  82.16863221,   3.23118799,
#          3.73529267,   3.5968192 ,   6.71979786,   3.60726687,
#          6.88622274,   5.0939236 ])

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.DataFrame(train[2, 0, :, :]).T.plot()
